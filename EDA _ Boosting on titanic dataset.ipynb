# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
Age=df['Age'].mean()
df['Age'].fillna(Age,inplace=True)

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
embarked=df['Embarked'].fillna('ffill',inplace=True)  
embarked

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %% [markdown]
# # Remove all the outliers

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df,x='Survived',y='Age')
plt.show()

# %%
df[(df['Survived']==0) &(df['Age']<=3)]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 7              8         0       3     Palsson, Master. Gosta Leonard    male
# 16            17         0       3               Rice, Master. Eugene    male
# 119          120         0       3  Andersson, Miss. Ellis Anna Maria  female
# 164          165         0       3       Panula, Master. Eino Viljami    male
# 205          206         0       3         Strom, Miss. Telma Matilda  female
# 297          298         0       1       Allison, Miss. Helen Loraine  female
# 374          375         0       3         Palsson, Miss. Stina Viola  female
# 386          387         0       3    Goodwin, Master. Sidney Leonard    male
# 642          643         0       3      Skoog, Miss. Margit Elizabeth  female
# 824          825         0       3       Panula, Master. Urho Abraham    male
#
#      Age  SibSp  Parch   Ticket      Fare Embarked
# 7    2.0      3      1   349909   21.0750        S
# ...

# %%
df.drop([7,16,119,164,205,297,374,386,642,824],inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df,x='Survived',y='Age')
plt.show()

# %%
df[(df['Survived']==0) & (df['Age']<=8)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 50            51         0       3               Panula, Master. Juha Niilo
# 63            64         0       3                    Skoog, Master. Harald
# 171          172         0       3                     Rice, Master. Arthur
# 278          279         0       3                       Rice, Master. Eric
# 787          788         0       3                Rice, Master. George Hugh
# 813          814         0       3       Andersson, Miss. Ebba Iris Alfrida
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
#
#         Sex  Age  SibSp  Parch   Ticket     Fare Embarked
# 24   female  8.0      3      1   349909  21.0750        S
# 50     male  7.0      4      1  3101295  39.6875        S
# 63     male  4.0      3      2   347088  27.9000        S
# ...

# %%
df.drop([24,50,63,171,278,787,813,850],inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df,x='Survived',y='Age')
plt.show()

# %%
df[(df['Survived']==0) & (df['Age']>=56)]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 33            34         0       2              Wheadon, Mr. Edward H    male
# 54            55         0       1     Ostby, Mr. Engelhart Cornelius    male
# 94            95         0       3                  Coxon, Mr. Daniel    male
# 96            97         0       1          Goldschmidt, Mr. George B    male
# 116          117         0       3               Connors, Mr. Patrick    male
# 170          171         0       1          Van der hoef, Mr. Wyckoff    male
# 174          175         0       1            Smith, Mr. James Clinch    male
# 232          233         0       2          Sjostedt, Mr. Ernst Adolf    male
# 252          253         0       1          Stead, Mr. William Thomas    male
# 280          281         0       3                   Duane, Mr. Frank    male
# 326          327         0       3          Nysveen, Mr. Johan Hansen    male
# ...

# %%
df.drop([33,54,94,96,116,170,174,232,252,280,326,438,456,467,487,493,545,555,625,626,659,672,684,694,745,772,851],inplace=True)

# %%
df[(df['Survived']==1) & (df['Age']>=58)]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 195          196         1       1
# 268          269         1       1
# 275          276         1       1
# 366          367         1       1
# 483          484         1       3
# 570          571         1       2
# 587          588         1       1
# 630          631         1       1
# 829          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 195                              Lurette, Miss. Elise  female  58.0      0
# 268     Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 483                            Turkula, Mrs. (Hedwig)  female  63.0      0
# ...

# %%
df.drop([11,195,268,275,366,483,570,587,630,829],inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df,x='Survived',y='Age')
plt.show()

# %%
df[(df['Survived']==1) & (df['Age']>47)]
# Out:
#      PassengerId  Survived  Pclass  \
# 15            16         1       2
# 52            53         1       1
# 259          260         1       2
# 299          300         1       1
# 449          450         1       1
# 453          454         1       1
# 458          459         1       2
# 460          461         1       1
# 496          497         1       1
# 513          514         1       1
# 526          527         1       2
# 556          557         1       1
# 571          572         1       1
# 591          592         1       1
# 599          600         1       1
# 645          646         1       1
# 647          648         1       1
# 660          661         1       1
# 712          713         1       1
# 754          755         1       2
# 765          766         1       1
# 774          775         1       2
# 796          797         1       1
# 820          821         1       1
# 857          858         1       1
# ...

# %%
df.drop([15,52,259,299,449,453,458,460,496,513,526,556,571,591,599,645,647,660,712,754,765,774,796,820,857,862,879],inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df,x='Survived',y='Age')
plt.show()

# %%
df[(df['Survived']==0) & (df['Age']>47)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 124          125         0       1              White, Mr. Percival Wayland
# 150          151         0       2               Bateman, Rev. Robert James
# 152          153         0       3                         Meo, Mr. Alfonzo
# 155          156         0       1              Williams, Mr. Charles Duane
# 177          178         0       1               Isham, Miss. Ann Elizabeth
# 222          223         0       3                  Green, Mr. George Henry
# 249          250         0       2            Carter, Rev. Ernest Courtenay
# 262          263         0       1                        Taussig, Mr. Emil
# 317          318         0       2                     Moraweck, Dr. Ernest
# 406          407         0       3         Widegren, Mr. Carl/Charles Peter
# ...

# %%
df.drop([6,124,150,152,155,177,222,249,262,317,406,434,463,482,492,544,582,597,631,695,698,714,723,736,771],inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df,x='Survived',y='Age')
plt.show()

# %%
df[(df['Survived']==0) & (df['Age']>46)]
# Out:
#      PassengerId  Survived  Pclass  \
# 110          111         0       1
# 132          133         0       3
# 462          463         0       1
# 515          516         0       1
# 586          587         0       2
# 592          593         0       3
# 662          663         0       1
# 873          874         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 110                  Porter, Mr. Walter Chamberlain    male  47.0      0
# 132  Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0      1
# 462                               Gee, Mr. Arthur H    male  47.0      0
# 515                    Walker, Mr. William Anderson    male  47.0      0
# 586                         Jarvis, Mr. John Denzil    male  47.0      0
# 592                      Elsbury, Mr. William James    male  47.0      0
# 662                      Colley, Mr. Edward Pomeroy    male  47.0      0
# ...

# %%
df.drop([110,132,462,515,586,592,662,873],inplace=True)

# %%
df[(df['Survived']==0) & (df['Age']<=10)]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 147          148         0       3       Ford, Miss. Robina Maggie "Ruby"
# 182          183         0       3  Asplund, Master. Clarence Gustaf Hugo
# 419          420         0       3              Van Impe, Miss. Catharina
# 480          481         0       3         Goodwin, Master. Harold Victor
# 541          542         0       3   Andersson, Miss. Ingeborg Constanzia
# 634          635         0       3                     Skoog, Miss. Mabel
# 819          820         0       3           Skoog, Master. Karl Thorsten
# 852          853         0       3                Boulos, Miss. Nourelain
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Embarked
# 147  female   9.0      2      2  W./C. 6608  34.3750        S
# 182    male   9.0      4      2      347077  31.3875        S
# 419  female  10.0      0      2      345773  24.1500        S
# ...

# %%
df.drop([147,182,419,480,541,634,819,852],inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df,x='Survived',y='Age')
plt.show()

# %%
df[(df['Survived']==0) & (df['Age']>=44)]
# Out:
#      PassengerId  Survived  Pclass  \
# 62            63         0       1
# 92            93         0       1
# 129          130         0       3
# 160          161         0       3
# 167          168         0       3
# 203          204         0       3
# 236          237         0       2
# 245          246         0       1
# 276          277         0       3
# 331          332         0       1
# 339          340         0       1
# 362          363         0       3
# 397          398         0       2
# 536          537         0       1
# 603          604         0       3
# 696          697         0       3
# 789          790         0       1
# 854          855         0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 62                       Harris, Mr. Henry Birkhardt    male  45.0      1
# 92                       Chaffee, Mr. Herbert Fuller    male  46.0      1
# ...

# %%
df.drop([62,92,129,160,167,203,236,245,276,331,339,362,397,536,603,696,79,854],inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df,x='Survived',y='Age')
plt.show()

# %%
df[(df['Survived']==0) & (df['Age']>=40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 30            31         0       1
# 35            36         0       1
# 40            41         0       3
# 149          150         0       2
# 153          154         0       3
# 188          189         0       3
# 197          198         0       3
# 217          218         0       2
# 254          255         0       3
# 263          264         0       1
# 314          315         0       2
# 349          350         0       3
# 360          361         0       3
# 525          526         0       3
# 561          562         0       3
# 638          639         0       3
# 661          662         0       3
# 668          669         0       3
# 678          679         0       3
# 699          700         0       3
# 761          762         0       3
# 789          790         0       1
# 818          819         0       3
# 845          846         0       3
# 860          861         0       3
#
# ...

# %%
df.drop([30,35,40,149,153,188,197,217,254,263,314,349,360,525,561,638,661,668,678,761,789,818,845,860],inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df,x='Survived',y='Age')
plt.show()

# %% [markdown]
# #  Handle the Skewness

# %%
from scipy.stats import skew
sns.distplot(df['Fare'])
skew(df['Fare'])
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 4.944046612252632

# %%
sns.distplot(df['Parch'])
skew(df['Parch'])
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 2.731582327715983

# %%
sns.distplot(df['SibSp'])
skew(df['SibSp'])
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 4.422708378358444

# %%
sns.distplot(df['Age'])
skew(df['Age'])
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# -0.8452641088617782

# %%
sns.distplot(df['Survived'])
skew(df['Survived'])
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.3294496041221985

# %%
sns.distplot(df['Pclass'])
skew(df['Pclass'])
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# -0.7906450758779726

# %% [markdown]
# # 	 plot chart for correlation

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True);
plt.show()

# %%
df['Fare'] = np.log(1+df['Fare'])
skew(df['Fare'])
# Out:
# 0.5583736292434913

# %%
sns.distplot(df['Fare'])
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
df['Parch'] = np.log(1+df['Parch'])
skew(df['Parch'])
# Out:
# 1.7713744544952768

# %%
sns.distplot(df['Parch'])
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Parch', ylabel='Density'>

# %%
df['SibSp'] = np.log(1+df['SibSp'])
skew(df['SibSp'])
# Out:
# 1.8231018251149185

# %%
sns.distplot(df['SibSp'])
# Out:
# C:\Users\ashis\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SibSp', ylabel='Density'>

# %%
df['title'] =df['Name'].str.split(',|\\.',expand = True)[1] 
df['title'] = df['title'].str.strip()
df['title'].value_counts()
# Out:
# Mr              430
# Miss            161
# Mrs              98
# Master           26
# Dr                3
# Mlle              2
# Rev               2
# Mme               1
# Ms                1
# Jonkheer          1
# the Countess      1
# Name: title, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0  0.693147
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  0.693147
# 2                             Heikkinen, Miss. Laina  female  26.0  0.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  0.693147
# 4                           Allen, Mr. William Henry    male  35.0  0.000000
#
#    Parch            Ticket      Fare Embarked title
# 0    0.0         A/5 21171  2.110213        S    Mr
# 1    0.0          PC 17599  4.280593        C   Mrs
# 2    0.0  STON/O2. 3101282  2.188856        S  Miss
# 3    0.0            113803  3.990834        S   Mrs
# ...

# %% [markdown]
# # Use Encoding and encode all the categorical data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df1=df.drop(['Name','Ticket'],axis=1)
df1.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age     SibSp  Parch      Fare  \
# 0            1         0       3    male  22.0  0.693147    0.0  2.110213
# 1            2         1       1  female  38.0  0.693147    0.0  4.280593
# 2            3         1       3  female  26.0  0.000000    0.0  2.188856
# 3            4         1       1  female  35.0  0.693147    0.0  3.990834
# 4            5         0       3    male  35.0  0.000000    0.0  2.202765
#
#   Embarked title
# 0        S    Mr
# 1        C   Mrs
# 2        S  Miss
# 3        S   Mrs
# 4        S    Mr

# %%
data_encoding=df1.select_dtypes('object').columns
data_encoding
# Out:
# Index(['Sex', 'Embarked', 'title'], dtype='object')

# %%
for i in data_encoding:
    df1[i]=le.fit_transform(df1[i])
df1.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age     SibSp  Parch      Fare  \
# 0            1         0       3    1  22.0  0.693147    0.0  2.110213
# 1            2         1       1    0  38.0  0.693147    0.0  4.280593
# 2            3         1       3    0  26.0  0.000000    0.0  2.188856
# 3            4         1       1    0  35.0  0.693147    0.0  3.990834
# 4            5         0       3    1  35.0  0.000000    0.0  2.202765
#
#    Embarked  title
# 0         2      6
# 1         0      7
# 2         2      3
# 3         2      7
# 4         2      6

# %%
df['Age'].value_counts()
# Out:
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
# 19.000000     25
# 21.000000     24
# 30.000000     24
# 25.000000     23
# 36.000000     22
# 29.000000     20
# 26.000000     18
# 32.000000     18
# 27.000000     18
# 35.000000     18
# 31.000000     17
# 16.000000     17
# 20.000000     15
# 33.000000     15
# 23.000000     15
# 34.000000     15
# 39.000000     14
# 17.000000     13
# 38.000000     11
# 42.000000      7
# 4.000000       7
# 40.000000      6
# 37.000000      6
# 14.000000      6
# 3.000000       5
# 1.000000       5
# 15.000000      5
# 45.000000      5
# 11.000000      4
# 5.000000       4
# 2.000000       3
# 44.000000      3
# 32.500000      2
# 28.500000      2
# 8.000000       2
# 41.000000      2
# 9.000000       2
# 0.830000       2
# 0.750000       2
# 30.500000      2
# 6.000000       2
# 13.000000      2
# 0.420000       1
# 23.500000      1
# 24.500000      1
# 0.920000       1
# 47.000000      1
# ...

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
col=['PassengerId','Pclass','Sex','Age','SibSp','Parch','Fare','Embarked','title']
df2=df1[col]
scaler=MinMaxScaler()
#df2=df1.iloc[:,:]
df2[:]=scaler.fit_transform(df2[:])
df2.head()
# Out:
# <ipython-input-62-3a76e304b967>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[:]=scaler.fit_transform(df2[:])
# C:\Users\ashis\anaconda3\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
#    PassengerId  Pclass  Sex       Age     SibSp  Parch      Fare  Embarked  \
# 0     0.000000     1.0  1.0  0.463289  0.315465    0.0  0.338125  0.666667
# ...

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked', 'title'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x=df2[['Pclass','Sex','Age','Embarked','title']]
y=df1['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=10)

# %%
print('shape of x_train:',x_train.shape)
print('shape of y_train:',y_train.shape)
print('shape of x_test:',x_test.shape)
print('shape of y_test:',y_test.shape)
# Out:
# shape of x_train: (508, 5)
# shape of y_train: (508,)
# shape of x_test: (218, 5)
# shape of y_test: (218,)

# %% [markdown]
# # Gradient Boosting Classification model

# %%
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(n_estimators = 50, learning_rate = 0.05)
gbcl = gbcl.fit(x_train, y_train)
test_pred = gbcl.predict(x_test)
gbcl_score=gbcl.score(x_test , y_test)
print("The Gradient Boost classifier model accuracy is {}".format(gbcl_score))
print("The confusion matrix of Gradient Boost classifier model is")
print(metrics.confusion_matrix(y_test,y_test))
# Out:
# The Gradient Boost classifier model accuracy is 0.7889908256880734
# The confusion matrix of Gradient Boost classifier model is
# [[117   0]
#  [  0 101]]

# %%
y_pred=gbcl.predict_proba(x_test)
y_pred
# Out:
# array([[0.86887738, 0.13112262],
#        [0.09862996, 0.90137004],
#        [0.86887738, 0.13112262],
#        [0.09856005, 0.90143995],
#        [0.86887738, 0.13112262],
#        [0.26533284, 0.73466716],
#        [0.86887738, 0.13112262],
#        [0.86887738, 0.13112262],
#        [0.86887738, 0.13112262],
#        [0.09751116, 0.90248884],
#        [0.54763769, 0.45236231],
#        [0.07902144, 0.92097856],
#        [0.54763769, 0.45236231],
#        [0.09751116, 0.90248884],
#        [0.09751116, 0.90248884],
#        [0.09487496, 0.90512504],
#        [0.86231168, 0.13768832],
#        [0.86887738, 0.13112262],
#        [0.11530153, 0.88469847],
#        [0.86887738, 0.13112262],
#        [0.59122847, 0.40877153],
#        [0.54763769, 0.45236231],
#        [0.32737048, 0.67262952],
#        [0.65878565, 0.34121435],
#        [0.86887738, 0.13112262],
#        [0.86887738, 0.13112262],
#        [0.32737048, 0.67262952],
#        [0.86887738, 0.13112262],
# ...

# %% [markdown]
# # Ada Boosting Classification model

# %%
from sklearn.ensemble import AdaBoostClassifier
my_ada_clf = AdaBoostClassifier()

# %%
my_ada_clf.fit(x_train,y_train)
my_ada_preds = my_ada_clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, my_ada_preds))
# Out:
# 0.7798165137614679

# %% [markdown]
# # Extreme Gradient Boosting model

# %%
from xgboost import XGBClassifier

# %%
my_xgb_clf = XGBClassifier(booster = 'gbtree')
my_xgb_clf.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
my_xgb_preds = my_xgb_clf.predict(x_test)

# %%
print(accuracy_score(y_test, my_xgb_preds))
# Out:
# 0.8027522935779816
